# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Data/raw/customer_churn_dataset-1.csv")

# %%
df.head()
# Out:
#   Customer_ID   Age  Tenure_Months Subscription_Plan Billing_Frequency  \
# 0   CUST10000  56.0              6             Basic           Monthly
# 1   CUST10001  46.0             15           Premium            Annual
# 2   CUST10002  32.0             18          Standard           Monthly
# 3   CUST10003  60.0             32           Premium            Annual
# 4   CUST10004  25.0             11          Standard           Monthly
#
#    Monthly_Charges  Login_Count_30D  Login_Count_7D  Usage_Minutes_30D  \
# 0           449.04               17              11                262
# 1          1194.07               10               6                209
# 2           736.96               19              18                209
# 3          1061.74               19               7                223
# 4           550.54               14               7                233
#
#    Usage_Minutes_7D  Avg_Session_Minutes_30D  Avg_Session_Minutes_7D  \
# ...

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (3000, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer_ID              3000 non-null   str
#  1   Age                      2970 non-null   float64
#  2   Tenure_Months            3000 non-null   int64
#  3   Subscription_Plan        3000 non-null   str
#  4   Billing_Frequency        3000 non-null   str
#  5   Monthly_Charges          2970 non-null   float64
#  6   Login_Count_30D          3000 non-null   int64
#  7   Login_Count_7D           3000 non-null   int64
#  8   Usage_Minutes_30D        3000 non-null   int64
#  9   Usage_Minutes_7D         3000 non-null   int64
#  10  Avg_Session_Minutes_30D  3000 non-null   float64
#  11  Avg_Session_Minutes_7D   3000 non-null   float64
#  12  Support_Tickets          3000 non-null   int64
#  13  Open_Tickets             3000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID                 0
# Age                        30
# Tenure_Months               0
# Subscription_Plan           0
# Billing_Frequency           0
# Monthly_Charges            30
# Login_Count_30D             0
# Login_Count_7D              0
# Usage_Minutes_30D           0
# Usage_Minutes_7D            0
# Avg_Session_Minutes_30D     0
# Avg_Session_Minutes_7D      0
# Support_Tickets             0
# Open_Tickets                0
# Avg_Resolution_Hours       30
# Payment_Delays              0
# Discount_Percent            0
# NPS_Score                  30
# Days_Since_Last_Login       0
# Churn                       0
# dtype: int64
